# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Titanic-Dataset.csv")

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.tail
# Out:
# <bound method NDFrame.tail of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]>

# %%
df.shape
# Out:
# (891, 12)

# %%
df["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df["Age"].min()
# Out:
# np.float64(0.42)

# %%
df["Age"].max()
# Out:
# np.float64(80.0)

# %%
plt.figure(figsize=(8,6))
plt.hist(df["Age"],bins=20,color='purple',edgecolor='black')
plt.title("Histogram of Age")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(df['Sex'],bins=10,color='orange',edgecolor='yellow')
plt.title("Histogram of Sex")
plt.xlabel('Sex')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(3,3))
sns.countplot(x='Survived', data=df, palette=['red', 'green'])
plt.title("Target Class Distribution")
plt.xlabel("Class")
plt.ylabel("Count")
plt.xticks(ticks=[0, 1], labels=['Not Survived (0)', 'Survived (1)'])
plt.show()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_10224\3827757826.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Survived', data=df, palette=['red', 'green'])

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df["Age"].fillna(df["Age"].mean(),inplace=True)
df["Cabin"].fillna(df["Cabin"].mode()[0],inplace=True)
df["Embarked"].fillna(df["Embarked"].mode()[0],inplace=True)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_10224\911034054.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(df["Age"].mean(),inplace=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_10224\911034054.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Cabin"].fillna(df["Cabin"].mode()[0],inplace=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_10224\911034054.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Embarked"].fillna(df["Embarked"].mode()[0],inplace=True)

# %%
sex_counts=df['Sex'].value_counts()
plt.figure(figsize=(8,6))
plt.pie(sex_counts,labels=sex_counts.index,autopct="%1.1f%%",startangle=90)
plt.title("Distribution of Sex")
plt.axis("equal")
plt.show()

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
df["Sex"]=label_encoder.fit_transform(df["Sex"])
df["Cabin"]=label_encoder.fit_transform(df["Cabin"])
df["Name"]=label_encoder.fit_transform(df["Name"])

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  Name  Sex   Age  SibSp  Parch  \
# 0            1         0       3   108    1  22.0      1      0
# 1            2         1       1   190    0  38.0      1      0
# 2            3         1       3   353    0  26.0      0      0
# 3            4         1       1   272    0  35.0      1      0
# 4            5         0       3    15    1  35.0      0      0
#
#              Ticket     Fare  Cabin Embarked
# 0         A/5 21171   7.2500     47        S
# 1          PC 17599  71.2833     81        C
# 2  STON/O2. 3101282   7.9250     47        S
# 3            113803  53.1000     55        S
# 4            373450   8.0500     47        S

# %%
#feature selection
x=df.drop(columns=["Survived","Pclass","Age","SibSp","Parch","Fare","Ticket","Embarked"])
y=df["Survived"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42,stratify=y)

# %%
#model building evaluation
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(n_estimators=100, max_depth=10)
rfc.fit(x_train,y_train)
Predict=(rfc.predict(x_test))
accuracy=accuracy_score(y_test,Predict)
print(f"Accuracy:{accuracy:.2f}")
cm=confusion_matrix(y_test,Predict)
labels=["Not Survived(0)","Survived(1)"]
sns.heatmap(cm, annot=True, fmt="d", cmap="magma",
xticklabels=labels, yticklabels=labels)
plt.xlabel("Preidcteed")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
Report=classification_report(y_test,Predict,target_names=["Not Survived(0)","Survived(1)"])
print("Classification Report:\n",Report)
# Out:
# Accuracy:0.77
# Classification Report:
#                   precision    recall  f1-score   support
#
# Not Survived(0)       0.79      0.85      0.82       110
#     Survived(1)       0.72      0.64      0.68        69
#
#        accuracy                           0.77       179
#       macro avg       0.75      0.74      0.75       179
#    weighted avg       0.76      0.77      0.76       179

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import(accuracy_score,classification_report,confusion_matrix,recall_score,precision_score,f1_score)
X = df.drop(['PassengerId', 'Name', 'Ticket', 'Survived'], axis=1)
X = df.drop(['PassengerId', 'Name', 'Ticket', 'Survived'], axis=1)
X = pd.get_dummies(X, drop_first=True)

y = df['Survived']
scaler=StandardScaler()
X=scaler.fit_transform(X)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)  # Apply transform, not fit_transform again

model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
y_pred=model.predict(x_test)
acc=accuracy_score(y_test,y_pred)
print(f"Accuracy: {accuracy*100: .2f}%")
recall=recall_score(y_test,y_pred)
print(f"Recall :{recall*100:.2f}%")
precision=precision_score(y_test,y_pred)
print(f"Precision:{precision*100:.2f}%")
f1=f1_score(y_test,y_pred)
print(f"F1 score:{f1*100:.2f}%")
# Out:
# Accuracy:  76.54%
# Recall :83.33%
# Precision:78.95%
# F1 score:81.08%

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.87        54
#            1       0.79      0.83      0.81        36
#
#     accuracy                           0.84        90
#    macro avg       0.84      0.84      0.84        90
# weighted avg       0.85      0.84      0.85        90

# %%
conf_matrix=confusion_matrix(y_test,y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix,annot=True,fmt='d',cmap="Reds",
xticklabels=['Not Survived','Survived'],yticklabels=['Not Survived','Survived'])
plt.title('Confusion Matrix')
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.87        54
#            1       0.79      0.83      0.81        36
#
#     accuracy                           0.84        90
#    macro avg       0.84      0.84      0.84        90
# weighted avg       0.85      0.84      0.85        90

# %%
from sklearn.naive_bayes import GaussianNB
model=GaussianNB()

# %%
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=model.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy*100:.2f}%")
recall = recall_score(y_test, y_pred)

print(f"Recall: {recall*100:.2f}%")
precision = precision_score(y_test, y_pred)

print(f"Precision: {precision*100:.2f}%")

f1 = f1_score(y_test, y_pred)
print(f"F1 Score: {f1*100:.2f}%")
# Out:
# Accuracy: 83.33%
# Recall: 83.33%
# Precision: 76.92%
# F1 Score: 80.00%

# %%
print(classification_report(y_test,y_pred))
conf_matrix=confusion_matrix(y_test,y_pred)
plt.figure(figsize=(10,6))
sns.heatmap(conf_matrix,annot=True,fmt="d",cmap="Greens",xticklabels=["Not Survived","Survived"],yticklabels=["Not Survived","Survived"])
plt.title("Confusion Matrix")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.83      0.86        54
#            1       0.77      0.83      0.80        36
#
#     accuracy                           0.83        90
#    macro avg       0.83      0.83      0.83        90
# weighted avg       0.84      0.83      0.83        90
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
from sklearn.svm import SVC
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)
model=SVC(kernel='rbf')

# %%
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)
model.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred=model.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_pred)
print(f"Accuracy:{accuracy*100:.2f}%")
recall=recall_score(y_test,y_pred)
print(f"Recall:{recall*100:.2f}%")
precision=precision_score(y_test,y_pred)
print(f"Precision:{precision*100:.2f}%")
f1=f1_score(y_test,y_pred)
print(f"F1:{f1*100:.2f}%")
# Out:
# Accuracy:80.45%
# Recall:65.00%
# Precision:73.58%
# F1:69.03%

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='magma',
            xticklabels=['Not Survived', 'Survived'],
            yticklabels=['Not Survived', 'Survived'])
plt.title('Confusion Matrix')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=4)

# %%
dtree=DecisionTreeClassifier(criterion='gini',max_depth=5)
dtree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
train_accuracies=[]
test_accuracies=[]
max_depths=range(1,6)
for depth in max_depths:
    dtree=DecisionTreeClassifier(criterion='Gini',max_depth=max)
    dtree.fit(x_train,y_train)
    train_accuracy=accuracy_score(y_train,dtree.predict(x_train))*100
    test_accuracy=accuracy_score(y_test,dtree.predict(x_test))*100
    train_accuracies=(max_depths,tests_accuracies,
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       3 max_depths=range(1,6)
#       4 for depth in max_depths:
# ----> 5     dtree=DecisionTreeClassifier(criterion='Gini',max_depth=max)
#       6     dtree.fit(x_train,y_train)
#       7     train_accuracy=accuracy_score(y_train,dtree.predict(x_train))*100
#
# NameError: name 'DecisionTreeClassifier' is not defined
